# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- --------------
# anyio                     4.8.0
# appnope                   0.1.4
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 3.0.0
# async-lru                 2.0.4
# attrs                     25.1.0
# babel                     2.17.0
# beautifulsoup4            4.13.3
# bleach                    6.2.0
# certifi                   2025.1.31
# cffi                      1.17.1
# charset-normalizer        3.4.1
# comm                      0.2.2
# contourpy                 1.3.1
# cycler                    0.12.1
# debugpy                   1.8.12
# decorator                 5.2.1
# defusedxml                0.7.1
# executing                 2.2.0
# fastjsonschema            2.21.1
# fonttools                 4.56.0
# fqdn                      1.5.1
# h11                       0.14.0
# httpcore                  1.0.7
# ...
